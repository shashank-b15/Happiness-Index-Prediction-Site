# %%
import warnings
warnings.filterwarnings('ignore')
import pandas as pd 
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
 
 
 
data1=pd.read_csv('Students_dataset.csv')

# %%
data1.head()
# Out:
#      Levels Environment Competitive  Classes         Lab  Sports  Toilet  \
# 0      hard   knowledge      highly        6  not always  02-Mar     bad
# 1  moderate  Assessment    moderate        6  not always  02-Mar  better
# 2      easy     learner    moderate        6         yes  02-Mar  better
# 3      hard  Assessment      highly        8  not always  06-Aug     bad
# 4  moderate   knowledge    moderate        8          no  02-Mar     bad
#
#   Sports_Competition Students_per_class Langugae  Timings     Meetings  Fests  \
# 0              never              21-30  english        7     annually   once
# 1          sometimes              21-30  english        7    Quarterly  twice
# 2              never              41-50    hindi        5    Quarterly  twice
# 3              never              21-30   telugu        7    Quarterly   once
# 4          sometimes              41-50    hindi        6  half yearly  twice
#
# ...

# %%
data1.tail()
# Out:
#         Levels Environment Competitive  Classes  Lab  Sports   Toilet  \
# 2995      easy   knowledge    moderate        8  yes  06-Aug   better
# 2996  moderate  Assessment    moderate        6  yes  06-Aug  hygiene
# 2997      hard  Assessment    moderate        8  yes  04-May      bad
# 2998      easy  Assessment    moderate       10   no  04-May   better
# 2999  moderate     learner      highly        8   no  06-Aug  hygiene
#
#      Sports_Competition Students_per_class Langugae  Timings     Meetings  \
# 2995              never              31-40   telugu        5    Quarterly
# 2996              never              21-30  english        7     annually
# 2997                yes              31-40   telugu        6     annually
# 2998              never              31-40   telugu        6     annually
# 2999          sometimes              41-50   telugu        7  half yearly
#
#       Fests Field_trips      Water Mid_day_meal  Quality_of_food Assessment  \
# ...

# %%
data1
# Out:
#         Levels Environment Competitive  Classes         Lab  Sports   Toilet  \
# 0         hard   knowledge      highly        6  not always  02-Mar      bad
# 1     moderate  Assessment    moderate        6  not always  02-Mar   better
# 2         easy     learner    moderate        6         yes  02-Mar   better
# 3         hard  Assessment      highly        8  not always  06-Aug      bad
# 4     moderate   knowledge    moderate        8          no  02-Mar      bad
# ...        ...         ...         ...      ...         ...     ...      ...
# 2995      easy   knowledge    moderate        8         yes  06-Aug   better
# 2996  moderate  Assessment    moderate        6         yes  06-Aug  hygiene
# 2997      hard  Assessment    moderate        8         yes  04-May      bad
# 2998      easy  Assessment    moderate       10          no  04-May   better
# 2999  moderate     learner      highly        8          no  06-Aug  hygiene
#
# ...

# %%
data1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3000 entries, 0 to 2999
# Data columns (total 20 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Levels              3000 non-null   object
#  1   Environment         3000 non-null   object
#  2   Competitive         3000 non-null   object
#  3   Classes             3000 non-null   int64
#  4   Lab                 3000 non-null   object
#  5   Sports              3000 non-null   object
#  6   Toilet              3000 non-null   object
#  7   Sports_Competition  3000 non-null   object
#  8   Students_per_class  3000 non-null   object
#  9   Langugae            3000 non-null   object
#  10  Timings             3000 non-null   int64
#  11  Meetings            3000 non-null   object
#  12  Fests               3000 non-null   object
#  13  Field_trips         3000 non-null   object
#  14  Water               3000 non-null   object
# ...

# %%
data1.isnull()
# Out:
#       Levels  Environment  Competitive  Classes    Lab  Sports  Toilet  \
# 0      False        False        False    False  False   False   False
# 1      False        False        False    False  False   False   False
# 2      False        False        False    False  False   False   False
# 3      False        False        False    False  False   False   False
# 4      False        False        False    False  False   False   False
# ...      ...          ...          ...      ...    ...     ...     ...
# 2995   False        False        False    False  False   False   False
# 2996   False        False        False    False  False   False   False
# 2997   False        False        False    False  False   False   False
# 2998   False        False        False    False  False   False   False
# 2999   False        False        False    False  False   False   False
#
#       Sports_Competition  Students_per_class  Langugae  Timings  Meetings  \
# ...

# %%
data1.isnull().sum()
# Out:
# Levels                0
# Environment           0
# Competitive           0
# Classes               0
# Lab                   0
# Sports                0
# Toilet                0
# Sports_Competition    0
# Students_per_class    0
# Langugae              0
# Timings               0
# Meetings              0
# Fests                 0
# Field_trips           0
# Water                 0
# Mid_day_meal          0
# Quality_of_food       0
# Assessment            0
# Region                0
# Happiness             0
# dtype: int64

# %%
data1.shape
# Out:
# (3000, 20)

# %%
data1.columns
# Out:
# Index(['Levels', 'Environment', 'Competitive', 'Classes', 'Lab', 'Sports',
#        'Toilet', 'Sports_Competition', 'Students_per_class', 'Langugae',
#        'Timings', 'Meetings', 'Fests', 'Field_trips', 'Water', 'Mid_day_meal',
#        'Quality_of_food', 'Assessment', 'Region', 'Happiness'],
#       dtype='object')

# %%
data1.describe()
# Out:
#            Classes      Timings    Happiness
# count  3000.000000  3000.000000  3000.000000
# mean      8.013333     6.014333     5.431134
# std       1.655920     0.809741     2.609064
# min       6.000000     5.000000     1.000183
# 25%       6.000000     5.000000     3.138293
# 50%       8.000000     6.000000     5.429874
# 75%      10.000000     7.000000     7.641261
# max      10.000000     7.000000     9.995829

# %% [markdown]
# ## Pre-processing

# %%
from sklearn.preprocessing import LabelEncoder 

lab=LabelEncoder()


data1['Environment']=lab.fit_transform(data1['Environment'])
data1['Competitive']=lab.fit_transform(data1['Competitive'])
data1['Lab']=lab.fit_transform(data1['Lab'])
data1['Sports']=lab.fit_transform(data1['Sports'])
data1['Toilet']=lab.fit_transform(data1['Toilet'])
data1['Sports_Competition']=lab.fit_transform(data1['Sports_Competition'])
data1['Students_per_class']=lab.fit_transform(data1['Students_per_class'])
data1['Langugae']=lab.fit_transform(data1['Langugae'])
data1['Meetings']=lab.fit_transform(data1['Meetings'])
data1['Fests']=lab.fit_transform(data1['Fests'])
data1['Field_trips']=lab.fit_transform(data1['Field_trips'])
data1['Mid_day_meal']=lab.fit_transform(data1['Mid_day_meal'])
data1['Quality_of_food']=lab.fit_transform(data1['Quality_of_food'])
data1['Assessment']=lab.fit_transform(data1['Assessment'])
data1['Region']=lab.fit_transform(data1['Region'])

# %%
data1['Levels']=lab.fit_transform(data1['Levels'])

# %%
data1['Water']=lab.fit_transform(data1['Water'])

# %%
data1.head()
# Out:
#    Levels  Environment  Competitive  Classes  Lab  Sports  Toilet  \
# 0       1            1            0        6    1       0       0
# 1       2            0            1        6    1       0       1
# 2       0            2            1        6    2       0       1
# 3       1            0            0        8    1       2       0
# 4       2            1            1        8    0       0       0
#
#    Sports_Competition  Students_per_class  Langugae  Timings  Meetings  Fests  \
# 0                   0                   0         0        7         1      1
# 1                   1                   0         0        7         0      2
# 2                   0                   2         1        5         0      2
# 3                   0                   0         2        7         0      1
# 4                   1                   2         1        6         2      2
#
#    Field_trips  Water  Mid_day_meal  Quality_of_food  Assessment  Region  \
# ...

# %% [markdown]
# ## Data Exploration

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
sns.countplot(x='Water',data=data1)
# Out:
# <AxesSubplot:xlabel='Water', ylabel='count'>

# %%
sns.countplot(x='Toilet',data=data1)
# Out:
# <AxesSubplot:xlabel='Toilet', ylabel='count'>

# %% [markdown]
# ## Data Splitting

# %%
x=data1.iloc[:,data1.columns!='Happiness']
y=data1.iloc[:,data1.columns=='Happiness']

#x.shape

#x.head()

x.head()
# Out:
#    Levels  Environment  Competitive  Classes  Lab  Sports  Toilet  \
# 0       1            1            0        6    1       0       0
# 1       2            0            1        6    1       0       1
# 2       0            2            1        6    2       0       1
# 3       1            0            0        8    1       2       0
# 4       2            1            1        8    0       0       0
#
#    Sports_Competition  Students_per_class  Langugae  Timings  Meetings  Fests  \
# 0                   0                   0         0        7         1      1
# 1                   1                   0         0        7         0      2
# 2                   0                   2         1        5         0      2
# 3                   0                   0         2        7         0      1
# 4                   1                   2         1        6         2      2
#
#    Field_trips  Water  Mid_day_meal  Quality_of_food  Assessment  Region
# ...

# %%
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score,confusion_matrix,recall_score, roc_curve, auc

# %%
xtrain,xtest,ytrain,ytest=train_test_split(x,y,test_size=0.3)

xtrain.head()

ytrain.head()
# Out:
#       Happiness
# 1711   9.208323
# 2213   3.102642
# 2117   4.191310
# 661    1.646868
# 549    2.398804

# %%
from sklearn.linear_model import LinearRegression
from sklearn.ensemble import AdaBoostRegressor,GradientBoostingRegressor,RandomForestRegressor
from sklearn.ensemble import StackingRegressor
#base models
base_models=[
    ('ABR',AdaBoostRegressor(n_estimators=50)),
    ('GBR',GradientBoostingRegressor(n_estimators=50)),
    ('RFR',RandomForestRegressor(n_estimators=50))
]
#Final Model
final_model=LinearRegression()

#stacking Regressor
classifier=StackingRegressor(estimators=base_models,final_estimator=final_model)
classifier.fit(xtrain,ytrain)
ypred=model.predict(xtest)

# %%
from sklearn.metrics import r2_score,mean_absolute_error,mean_squared_error
#Evaluation of Model
print("R2 Score " ,r2_score(ytest,ypred))
mse=mean_squared_error(ytest,ypred)
mae=mean_absolute_error(ytest,ypred)
print("MSE:",mse)
print("MAE:",mae)
print("RMSE :",np.sqrt(mse))

# %%
### Create a Pickle file using serialization 
import pickle
pickle_out = open("classifier.pkl","wb")
pickle.dump(classifier, pickle_out)
pickle_out.close()
